# %% [markdown]
# # Import packages; read in files

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
# Chloe's directory
# Set file path
#os.chdir("/Users/chloemaine/Documents/Chloe/BGSE/masters_project/raw_data")

# %%
# Read in files


#'ccs_multi_dx.csv' is downloaded from https://www.hcup-us.ahrq.gov/toolssoftware/ccs/Multi_Level_CCS_2015.zip
#It's Clinical Classification Software (CCS) that categorises ICD-9 codes developed by the Agency for Healthcare Research and Quality (AHRQ)
icds = pd.read_csv('../input_data/ccs_multi_dx.csv') # Diagnosis codes

#'diagnosis_icd.csv' is the DIAGNOSIS_ICD table from MIMIC
diagnoses = pd.read_csv('../input_data/diagnosis_icd.csv') 

#'patient_details.csv' is created from a combination of multiple tables from MIMIC LCP
#The process I followed is https://github.com/MIT-LCP/mimic-code/blob/master/concepts/demographics/icustay-detail.sql
patient_details = pd.read_csv('../input_data/patient_details.csv')

#icustays_collapsed table from bgse-dsc (processed icustays with backshifted dates)
intime_collapsed = pd.read_csv('../input_data/INTIME_COLLAPSED.csv')
intime_collapsed = intime_collapsed[['SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID', 'INTIME_COLLAPSED', 'OUTTIME_COLLAPSED']]

#'icustays.csv' is the ICUSTAYS table from MIMIC
icus = pd.read_csv('../input_data/icustays.csv').set_index('ICUSTAY_ID')

# %%
patient_details.head()
# Out:
#    subject_id  hadm_id  icustay_id gender                  dod  \
# 0           2   163353      243653      M                  NaN
# 1           3   145834      211552      M  2102-06-14 00:00:00
# 2           4   185777      294638      F                  NaN
# 3           5   178980      214757      M                  NaN
# 4           6   107064      228232      F                  NaN
#
#              admittime            dischtime  los_hospital  age ethnicity  \
# 0  2138-07-17 19:04:00  2138-07-21 15:48:00             4    0     ASIAN
# 1  2101-10-20 19:08:00  2101-10-31 13:58:00            11   76     WHITE
# 2  2191-03-16 00:28:00  2191-03-23 18:41:00             7   48     WHITE
# 3  2103-02-02 04:31:00  2103-02-04 12:15:00             2    0     ASIAN
# 4  2175-05-30 07:15:00  2175-06-15 16:00:00            16   66     WHITE
#
#   ethnicity_grouped admission_type  hospital_expire_flag  hospstay_seq  \
# 0             asian        NEWBORN                     0             1
# 1             white      EMERGENCY                     0             1
# 2             white      EMERGENCY                     0             1
# 3             asian        NEWBORN                     0             1
# 4             white       ELECTIVE                     0             1
#
#    first_hosp_stay               intime              outtime  los_icu  \
# 0             True  2138-07-17 21:20:07  2138-07-17 23:32:21      0.0
# 1             True  2101-10-20 19:10:11  2101-10-26 20:43:09      6.0
# 2             True  2191-03-16 00:29:31  2191-03-17 16:46:31      1.0
# 3             True  2103-02-02 06:04:24  2103-02-02 08:06:00      0.0
# 4             True  2175-05-30 21:30:54  2175-06-03 13:39:54      4.0
#
#    icustay_seq  first_icu_stay
# 0            1            True
# 1            1            True
# 2            1            True
# 3            1            True
# 4            1            True

# %%
patient_details.columns
# Out:
# Index(['subject_id', 'hadm_id', 'icustay_id', 'gender', 'dod', 'admittime',
#        'dischtime', 'los_hospital', 'age', 'ethnicity', 'ethnicity_grouped',
#        'admission_type', 'hospital_expire_flag', 'hospstay_seq',
#        'first_hosp_stay', 'intime', 'outtime', 'los_icu', 'icustay_seq',
#        'first_icu_stay'],
#       dtype='object')

# %%
patient_details.shape
# Out:
# (61532, 20)

# %%
intime_collapsed.shape
# Out:
# (61532, 5)

# %% [markdown]
# # Functions

# %%
def extract_category(ccs_group1):
    return ccs_g1_categories[ccs_group1]

# %% [markdown]
# # Dictionaries

# %%
#The Clinical Classification Software (CCS) categorizes ICD-9 coded diagnoses into clinically meaningful groups. 
#The categorization was developed by the Agency for Healthcare Research and Quality (AHRQ). 
#the AHRQ website: https://www.hcup-us.ahrq.gov/tools_software.jsp


ccs_g1_categories = {
   'Diseases of the digestive system': 'digestive',
   'Diseases of the circulatory system': 'circulatory',
   'Diseases of the genitourinary system': 'genitourinary',
   'Infectious and parasitic diseases': 'infectious|parasitic',
   'Endocrine; nutritional; and metabolic diseases and immunity disorders': 'metabolic|immunity',
   'Diseases of the respiratory system': 'respiratory',
   'Injury and poisoning': 'injury|poisoning',
   'Symptoms; signs; and ill-defined conditions and factors influencing health status': 'ill-defined',
   'Diseases of the blood and blood-forming organs': 'blood',
   'Certain conditions originating in the perinatal period': 'perinatal',
   'Residual codes; unclassified; all E codes [259. and 260.]': 'unclassified',
   'Neoplasms': 'neoplasms',
   'Diseases of the nervous system and sense organs': 'nervous',
   'Mental Illness': 'mental',
   'Congenital anomalies': 'congenital',
   'Diseases of the musculoskeletal system and connective tissue': 'musculoskeletal',
   'Diseases of the skin and subcutaneous tissue': 'skin',
   'Complications of pregnancy; childbirth; and the puerperium': 'pregnancy complications',
   'Mental illness': 'mental'
}

# %% [markdown]
# # Join diagnoses to icds and extract sepsis ids

# %%
print('ICDs')
print(icds.shape)
icds.iloc[1:5, :]
# Out:
# ICDs
# (15072, 9)
#   icd9_code  ccs_level1                         ccs_group1  ccs_level2  \
# 1     01001           1  Infectious and parasitic diseases         1.1
# 2     01002           1  Infectious and parasitic diseases         1.1
# 3     01003           1  Infectious and parasitic diseases         1.1
# 4     01004           1  Infectious and parasitic diseases         1.1
#
#             ccs_group2 ccs_level3         ccs_group3 ccs_level4 ccs_group4
# 1  Bacterial infection      1.1.1  Tuberculosis [1.]        NaN        NaN
# 2  Bacterial infection      1.1.1  Tuberculosis [1.]        NaN        NaN
# 3  Bacterial infection      1.1.1  Tuberculosis [1.]        NaN        NaN
# 4  Bacterial infection      1.1.1  Tuberculosis [1.]        NaN        NaN

# %%
diagnoses['ICD9_CODE'] = diagnoses['ICD9_CODE'].astype('str').str.strip() # removing any whitespaces
diagnoses = diagnoses.dropna(subset=['ICD9_CODE']) # look for missing values in 'ICD9_CODE'

icds['icd9_code'] = icds['icd9_code'].astype('str').str.strip()

print('Pre-merge:')
print('Diagnoses shape: ', diagnoses.shape)
print('icds shape: ', icds.shape)
joined = diagnoses.join(icds.set_index('icd9_code'), how='left', on='ICD9_CODE')
print('Post-merge:')
print('Joined shape:', joined.shape)

joined = joined[joined['ccs_group1'].notnull()]

print("The columns of joined are", joined.columns)
# Out:
# Pre-merge:
# Diagnoses shape:  (651047, 5)
# icds shape:  (15072, 9)
# Post-merge:
# Joined shape: (651047, 13)
# The columns of joined are Index(['ROW_ID', 'SUBJECT_ID', 'HADM_ID', 'SEQ_NUM', 'ICD9_CODE', 'ccs_level1',
#        'ccs_group1', 'ccs_level2', 'ccs_group2', 'ccs_level3', 'ccs_group3',
#        'ccs_level4', 'ccs_group4'],
#       dtype='object')

# %%
joined.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE  ccs_level1  \
# 0    3113         256   108811      1.0     53240         9.0
# 1    3114         256   108811      2.0     41071         7.0
# 2    3115         256   108811      3.0     53560         9.0
# 3    3116         256   108811      4.0     40390         7.0
# 4    3117         256   108811      5.0      5859        10.0
#
#                              ccs_group1  ccs_level2  \
# 0      Diseases of the digestive system         9.1
# 1    Diseases of the circulatory system         7.2
# 2      Diseases of the digestive system         9.4
# 3    Diseases of the circulatory system         7.1
# 4  Diseases of the genitourinary system        10.1
#
#                            ccs_group2 ccs_level3  \
# 0  Gastrointestinal hemorrhage [153.]     9.10.1
# 1               Diseases of the heart      7.2.3
# 2    Upper gastrointestinal disorders      9.4.3
# 3                        Hypertension      7.1.2
# 4      Diseases of the urinary system     10.1.3
#
#                                           ccs_group3 ccs_level4  \
# 0             Hemorrhage from gastrointestinal ulcer        NaN
# 1                 Acute myocardial infarction [100.]        NaN
# 2                    Gastritis and duodenitis [140.]    9.4.3.4
# 3  Hypertension with complications and secondary ...    7.1.2.1
# 4                      Chronic kidney disease [158.]        NaN
#
#                                 ccs_group4
# 0                                      NaN
# 1                                      NaN
# 2                               Duodenitis
# 3  Hypertensive heart and/or renal disease
# 4                                      NaN

# %%
#make column called category by transforming the 'ccs_group1' column and extracting the category

joined['category'] = joined['ccs_group1'].apply(extract_category)

# %%
joined.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE  ccs_level1  \
# 0    3113         256   108811      1.0     53240         9.0
# 1    3114         256   108811      2.0     41071         7.0
# 2    3115         256   108811      3.0     53560         9.0
# 3    3116         256   108811      4.0     40390         7.0
# 4    3117         256   108811      5.0      5859        10.0
#
#                              ccs_group1  ccs_level2  \
# 0      Diseases of the digestive system         9.1
# 1    Diseases of the circulatory system         7.2
# 2      Diseases of the digestive system         9.4
# 3    Diseases of the circulatory system         7.1
# 4  Diseases of the genitourinary system        10.1
#
#                            ccs_group2 ccs_level3  \
# 0  Gastrointestinal hemorrhage [153.]     9.10.1
# 1               Diseases of the heart      7.2.3
# 2    Upper gastrointestinal disorders      9.4.3
# 3                        Hypertension      7.1.2
# 4      Diseases of the urinary system     10.1.3
#
#                                           ccs_group3 ccs_level4  \
# 0             Hemorrhage from gastrointestinal ulcer        NaN
# 1                 Acute myocardial infarction [100.]        NaN
# 2                    Gastritis and duodenitis [140.]    9.4.3.4
# 3  Hypertension with complications and secondary ...    7.1.2.1
# 4                      Chronic kidney disease [158.]        NaN
#
#                                 ccs_group4       category
# 0                                      NaN      digestive
# 1                                      NaN    circulatory
# 2                               Duodenitis      digestive
# 3  Hypertensive heart and/or renal disease    circulatory
# 4                                      NaN  genitourinary

# %% [markdown]
# # Extract Patients who have sepsis
# - In the final csv that will be created, I will add a column that is a binary flag for sepsis or no sepsis (in addition to first_category).
# - This is in order to not lose the granularity of this information, when we only group diagnoses
# - note: the people who will have sepsis=True, will be a portion of those whose 'first_category' is infectious|parasitic

# %%
#icd9 code for sepsis
icds[icds['icd9_code'].str.contains('99591')]
# Out:
#     icd9_code  ccs_level1                         ccs_group1  ccs_level2  \
# 450     99591           1  Infectious and parasitic diseases         1.1
#
#               ccs_group2 ccs_level3                         ccs_group3  \
# 450  Bacterial infection      1.1.2  Septicemia (except in labor) [2.]
#
#     ccs_level4              ccs_group4
# 450    1.1.2.6  Unspecified septicemia

# %%
#extract those with sepsis
#this will be joined by subject_id and hadm_id at the end
patients_with_sepsis = joined[joined['ccs_group3'] == 'Septicemia (except in labor) [2.]']
patients_with_sepsis = patients_with_sepsis[['SUBJECT_ID', 'HADM_ID']]
patients_with_sepsis['sepsis'] = True
patients_with_sepsis = patients_with_sepsis.drop_duplicates().set_index(['SUBJECT_ID', 'HADM_ID'])

# %%
print('Patients with sepsis- shape: ',patients_with_sepsis.shape)
patients_with_sepsis.head()
# Out:
# Patients with sepsis- shape:  (8005, 1)
#                     sepsis
# SUBJECT_ID HADM_ID
# 1024       127666     True
# 4096       124383     True
# 72960      164620     True
# 74496      138943     True
# 9472       166597     True

# %%
patients_with_sepsis1 = patients_with_sepsis.reset_index()

# %%
patients_with_sepsis1.to_csv('../output_data/patients_with_sepsis.csv', index=False)

# %%
#more than one category per HADM_ID. so groupby HADM_ID to get the categories for each id
ids_to_categories = joined[['HADM_ID', 'category']].groupby('HADM_ID')['category'].apply(list).reset_index()

# %%
ids_to_categories['first_category'] = ids_to_categories['category'].apply(lambda x: x[0])

# %%
ids_to_categories.head()
# Out:
#    HADM_ID                                           category  \
# 0   100001  [metabolic|immunity, nervous, genitourinary, d...
# 1   100003  [digestive, blood, infectious|parasitic, diges...
# 2   100006  [respiratory, respiratory, respiratory, neopla...
# 3   100007  [digestive, circulatory, injury|poisoning, res...
# 4   100009  [circulatory, injury|poisoning, circulatory, m...
#
#        first_category
# 0  metabolic|immunity
# 1           digestive
# 2         respiratory
# 3           digestive
# 4         circulatory

# %%
# one hot encode categories, and join back onto the main dataframe
hadm_item = pd.get_dummies(ids_to_categories['category'].apply(pd.Series).stack()).sum(level = 0)
hadm_item = ids_to_categories.join(hadm_item)

# %%
hadm_item.columns = [col.lower() for col in hadm_item.columns]
hadm_item.head()
# Out:
#    hadm_id                                           category  \
# 0   100001  [metabolic|immunity, nervous, genitourinary, d...
# 1   100003  [digestive, blood, infectious|parasitic, diges...
# 2   100006  [respiratory, respiratory, respiratory, neopla...
# 3   100007  [digestive, circulatory, injury|poisoning, res...
# 4   100009  [circulatory, injury|poisoning, circulatory, m...
#
#        first_category  blood  circulatory  congenital  digestive  \
# 0  metabolic|immunity      0            2           0          2
# 1           digestive      1            1           0          5
# 2         respiratory      0            2           0          0
# 3           digestive      0            2           0          1
# 4         circulatory      1            9           0          0
#
#    genitourinary  ill-defined  infectious|parasitic  ...  mental  \
# 0              2            1                     0  ...       0
# 1              0            0                     1  ...       0
# 2              0            0                     0  ...       2
# 3              0            0                     0  ...       0
# 4              0            1                     0  ...       1
#
#    metabolic|immunity  musculoskeletal  neoplasms  nervous  perinatal  \
# 0                   5                1          0        2          0
# 1                   0                0          0        0          0
# 2                   1                0          1        0          0
# 3                   0                0          0        0          0
# 4                   4                0          0        0          0
#
#    pregnancy complications  respiratory  skin  unclassified
# 0                        0            0     1             0
# 1                        0            0     0             1
# 2                        0            3     0             0
# 3                        0            1     0             0
# 4                        0            0     0             1
#
# [5 rows x 21 columns]

# %%
def apply_ones(df):
    for column in df.drop(['hadm_id', 'category', 'first_category'], axis=1).columns:
        df[column] = df[column].apply(lambda x: 1 if x > 0 else 0)
    return df
        
    
    
#ignore apply ones because when we go into clustering, we want to count the number of diagnoses as a column
#hadm_item = apply_ones(hadm_item)

# %%
print('Pre-merge: ')
print('Patient details: ', patient_details.shape)
print('hadm_iten: ', hadm_item.shape)
admissions_with_diagnosis = patient_details.merge(hadm_item, how='inner', on='hadm_id')
print('Post-merge with hadm_item:')
print('Admissions with diagnosis:', admissions_with_diagnosis.shape)
# Out:
# Pre-merge:
# Patient details:  (61532, 20)
# hadm_iten:  (58929, 21)
# Post-merge with hadm_item:
# Admissions with diagnosis: (61525, 40)

# %%
admissions_with_diagnosis = admissions_with_diagnosis.join(icus, on='icustay_id')
print('Post-merge with icus:')
print('Admissions with diagnosis:', admissions_with_diagnosis.shape)
# Out:
# Post-merge with icus:
# Admissions with diagnosis: (61525, 51)

# %% [markdown]
# ## replace the intime column from patient_detials with the intime in icustays_trans_collapsed

# %%
#replace the intime column from patient_detials with the intime in intime_collapsed
#by joining on icustay_id

# %%
intime_collapsed.shape
# Out:
# (61532, 5)

# %%
print('Icu stay trans collapsed shape: ', intime_collapsed.shape)
intime_collapsed.head()
# Out:
# Icu stay trans collapsed shape:  (61532, 5)
#    SUBJECT_ID  HADM_ID  ICUSTAY_ID         INTIME_COLLAPSED  \
# 0        1026   103873      215365  2007-04-28 05:19:34 UTC
# 1        1970   144456      282130  2005-03-22 05:30:48 UTC
# 2        5145   182528      289297  2006-02-08 00:05:43 UTC
# 3        9967   171327      281112  2002-09-09 19:10:59 UTC
# 4       15763   105221      255354  2004-04-05 10:24:39 UTC
#
#          OUTTIME_COLLAPSED
# 0  2007-04-30 16:57:14 UTC
# 1  2005-03-29 17:17:07 UTC
# 2  2006-02-09 17:16:28 UTC
# 3  2002-09-18 16:56:11 UTC
# 4  2004-04-08 18:55:07 UTC

# %%
print('Admissions with diagnosis: Shape', admissions_with_diagnosis.shape)
admissions_with_diagnosis.head()
# Out:
# Admissions with diagnosis: Shape (61525, 51)
#    subject_id  hadm_id  icustay_id gender                  dod  \
# 0           2   163353      243653      M                  NaN
# 1           3   145834      211552      M  2102-06-14 00:00:00
# 2           4   185777      294638      F                  NaN
# 3           5   178980      214757      M                  NaN
# 4           6   107064      228232      F                  NaN
#
#              admittime            dischtime  los_hospital  age ethnicity  ...  \
# 0  2138-07-17 19:04:00  2138-07-21 15:48:00             4    0     ASIAN  ...
# 1  2101-10-20 19:08:00  2101-10-31 13:58:00            11   76     WHITE  ...
# 2  2191-03-16 00:28:00  2191-03-23 18:41:00             7   48     WHITE  ...
# 3  2103-02-02 04:31:00  2103-02-04 12:15:00             2    0     ASIAN  ...
# 4  2175-05-30 07:15:00  2175-06-15 16:00:00            16   66     WHITE  ...
#
#   SUBJECT_ID HADM_ID  DBSOURCE  FIRST_CAREUNIT  LAST_CAREUNIT FIRST_WARDID  \
# 0          2  163353   carevue            NICU           NICU           56
# 1          3  145834   carevue            MICU           MICU           12
# 2          4  185777   carevue            MICU           MICU           52
# 3          5  178980   carevue            NICU           NICU           56
# 4          6  107064   carevue            SICU           SICU           33
#
#   LAST_WARDID               INTIME              OUTTIME     LOS
# 0          56  2138-07-17 21:20:07  2138-07-17 23:32:21  0.0918
# 1          12  2101-10-20 19:10:11  2101-10-26 20:43:09  6.0646
# 2          52  2191-03-16 00:29:31  2191-03-17 16:46:31  1.6785
# 3          56  2103-02-02 06:04:24  2103-02-02 08:06:00  0.0844
# 4          33  2175-05-30 21:30:54  2175-06-03 13:39:54  3.6729
#
# [5 rows x 51 columns]

# %%
joined = admissions_with_diagnosis.set_index('icustay_id').join(intime_collapsed.set_index('ICUSTAY_ID'), how='outer', lsuffix='awd_', rsuffix='ic_').reset_index()
joined = joined.rename(columns={'index': 'icustay_id'})

# %%
admissions_with_diagnosis = joined
print('Post-merge shape: ', joined.shape)
# Out:
# Post-merge shape:  (61532, 55)

# %%
admissions_with_diagnosis.head()
# Out:
#    icustay_id  subject_id   hadm_id gender                  dod  \
# 0      200001     55973.0  152234.0      F  2182-11-26 00:00:00
# 1      200003     27513.0  163557.0      M  2199-10-17 00:00:00
# 2      200006     10950.0  189514.0      M  2160-05-14 00:00:00
# 3      200007     20707.0  129310.0      M                  NaN
# 4      200009     29904.0  129607.0      F                  NaN
#
#              admittime            dischtime  los_hospital   age  \
# 0  2181-11-18 16:04:00  2181-12-04 13:42:00          16.0  61.0
# 1  2199-08-02 17:02:00  2199-08-22 19:00:00          20.0  48.0
# 2  2159-09-03 11:27:00  2159-09-05 18:45:00           2.0  54.0
# 3  2109-02-17 10:02:00  2109-02-20 15:47:00           3.0  44.0
# 4  2189-11-30 10:45:00  2189-12-06 15:00:00           6.0  47.0
#
#               ethnicity  ... LAST_CAREUNIT FIRST_WARDID  LAST_WARDID  \
# 0  ASIAN - ASIAN INDIAN  ...          MICU         23.0         23.0
# 1                 WHITE  ...          SICU         57.0         57.0
# 2                 OTHER  ...          MICU         52.0         52.0
# 3                 WHITE  ...           CCU         57.0         57.0
# 4                 WHITE  ...          CSRU         15.0         15.0
#
#                 INTIME              OUTTIME     LOS SUBJECT_IDic_  HADM_IDic_  \
# 0  2181-11-25 19:06:12  2181-11-28 20:59:25  3.0786         55973      152234
# 1  2199-08-02 19:50:04  2199-08-08 17:09:18  5.8884         27513      163557
# 2  2159-09-03 11:28:14  2159-09-04 19:08:10  1.3194         10950      189514
# 3  2109-02-17 10:03:37  2109-02-18 17:03:12  1.2914         20707      129310
# 4  2189-11-30 10:34:32  2189-12-02 14:17:37  2.1549         29904      129607
#
#           INTIME_COLLAPSED        OUTTIME_COLLAPSED
# 0  2011-09-04 19:06:12 UTC  2011-09-07 20:59:23 UTC
# 1  2007-07-13 19:50:04 UTC  2007-07-19 17:09:21 UTC
# 2  2004-11-22 11:28:14 UTC  2004-11-23 19:08:10 UTC
# 3  2001-07-22 10:03:37 UTC  2001-07-23 17:03:13 UTC
# 4  2006-11-20 10:34:32 UTC  2006-11-22 14:17:35 UTC
#
# [5 rows x 55 columns]

# %%
admissions_with_diagnosis.shape
# Out:
# (61532, 55)

# %% [markdown]
# # Drop 'ethnicity' column because we have 'ethnicity_grouped' column

# %%
admissions_with_diagnosis = admissions_with_diagnosis.drop(['ethnicity'], axis=1)

# %% [markdown]
# # Check join

# %%
admissions_with_diagnosis.isnull().sum()
# Out:
# icustay_id                     0
# subject_id                     7
# hadm_id                        7
# gender                         7
# dod                        37348
# admittime                      7
# dischtime                      7
# los_hospital                   7
# age                            7
# ethnicity_grouped              7
# admission_type                 7
# hospital_expire_flag           7
# hospstay_seq                   7
# first_hosp_stay                7
# intime                         7
# outtime                       17
# los_icu                       17
# icustay_seq                    7
# first_icu_stay                 7
# category                       7
# first_category                 7
# blood                          7
# circulatory                    7
# congenital                     7
# digestive                      7
# genitourinary                  7
# ill-defined                    7
# infectious|parasitic           7
# injury|poisoning               7
# mental                         7
# metabolic|immunity             7
# musculoskeletal                7
# neoplasms                      7
# nervous                        7
# perinatal                      7
# pregnancy complications        7
# respiratory                    7
# skin                           7
# unclassified                   7
# ROW_ID                         7
# SUBJECT_IDawd_                 7
# HADM_IDawd_                    7
# DBSOURCE                       7
# FIRST_CAREUNIT                 7
# LAST_CAREUNIT                  7
# FIRST_WARDID                   7
# LAST_WARDID                    7
# INTIME                         7
# OUTTIME                       17
# LOS                           17
# SUBJECT_IDic_                  0
# HADM_IDic_                     0
# INTIME_COLLAPSED               0
# OUTTIME_COLLAPSED             10
# dtype: int64

# %% [markdown]
# # Binning age into groups
# - Max age is 100.
# - I bin ages into 5 groups.

# %%
def add_age_group(df):
    def group(x):
        if x >= 100:
            x = 99

        lower_bound = x // 20
        if lower_bound == 4:
            return '80-100'
        else:
            return f'{lower_bound * 20}-{(lower_bound + 1) * 20 - 1}'
    df['age_group'] = df['age'].apply(group)
    return df

# %%
admissions_with_diagnosis = add_age_group(admissions_with_diagnosis)
admissions_with_diagnosis.head()
# Out:
#    icustay_id  subject_id   hadm_id gender                  dod  \
# 0      200001     55973.0  152234.0      F  2182-11-26 00:00:00
# 1      200003     27513.0  163557.0      M  2199-10-17 00:00:00
# 2      200006     10950.0  189514.0      M  2160-05-14 00:00:00
# 3      200007     20707.0  129310.0      M                  NaN
# 4      200009     29904.0  129607.0      F                  NaN
#
#              admittime            dischtime  los_hospital   age  \
# 0  2181-11-18 16:04:00  2181-12-04 13:42:00          16.0  61.0
# 1  2199-08-02 17:02:00  2199-08-22 19:00:00          20.0  48.0
# 2  2159-09-03 11:27:00  2159-09-05 18:45:00           2.0  54.0
# 3  2109-02-17 10:02:00  2109-02-20 15:47:00           3.0  44.0
# 4  2189-11-30 10:45:00  2189-12-06 15:00:00           6.0  47.0
#
#   ethnicity_grouped  ... FIRST_WARDID  LAST_WARDID               INTIME  \
# 0             asian  ...         23.0         23.0  2181-11-25 19:06:12
# 1             white  ...         57.0         57.0  2199-08-02 19:50:04
# 2             other  ...         52.0         52.0  2159-09-03 11:28:14
# 3             white  ...         57.0         57.0  2109-02-17 10:03:37
# 4             white  ...         15.0         15.0  2189-11-30 10:34:32
#
#                OUTTIME     LOS SUBJECT_IDic_  HADM_IDic_  \
# 0  2181-11-28 20:59:25  3.0786         55973      152234
# 1  2199-08-08 17:09:18  5.8884         27513      163557
# 2  2159-09-04 19:08:10  1.3194         10950      189514
# 3  2109-02-18 17:03:12  1.2914         20707      129310
# 4  2189-12-02 14:17:37  2.1549         29904      129607
#
#           INTIME_COLLAPSED        OUTTIME_COLLAPSED  age_group
# 0  2011-09-04 19:06:12 UTC  2011-09-07 20:59:23 UTC  60.0-79.0
# 1  2007-07-13 19:50:04 UTC  2007-07-19 17:09:21 UTC  40.0-59.0
# 2  2004-11-22 11:28:14 UTC  2004-11-23 19:08:10 UTC  40.0-59.0
# 3  2001-07-22 10:03:37 UTC  2001-07-23 17:03:13 UTC  40.0-59.0
# 4  2006-11-20 10:34:32 UTC  2006-11-22 14:17:35 UTC  40.0-59.0
#
# [5 rows x 55 columns]

# %% [markdown]
# # Adding binary column for death

# %%
admissions_with_diagnosis['dod_exists'] = admissions_with_diagnosis['dod'].notnull()

# %%
admissions_with_diagnosis.head()
# Out:
#    icustay_id  subject_id   hadm_id gender                  dod  \
# 0      200001     55973.0  152234.0      F  2182-11-26 00:00:00
# 1      200003     27513.0  163557.0      M  2199-10-17 00:00:00
# 2      200006     10950.0  189514.0      M  2160-05-14 00:00:00
# 3      200007     20707.0  129310.0      M                  NaN
# 4      200009     29904.0  129607.0      F                  NaN
#
#              admittime            dischtime  los_hospital   age  \
# 0  2181-11-18 16:04:00  2181-12-04 13:42:00          16.0  61.0
# 1  2199-08-02 17:02:00  2199-08-22 19:00:00          20.0  48.0
# 2  2159-09-03 11:27:00  2159-09-05 18:45:00           2.0  54.0
# 3  2109-02-17 10:02:00  2109-02-20 15:47:00           3.0  44.0
# 4  2189-11-30 10:45:00  2189-12-06 15:00:00           6.0  47.0
#
#   ethnicity_grouped  ... LAST_WARDID               INTIME  \
# 0             asian  ...        23.0  2181-11-25 19:06:12
# 1             white  ...        57.0  2199-08-02 19:50:04
# 2             other  ...        52.0  2159-09-03 11:28:14
# 3             white  ...        57.0  2109-02-17 10:03:37
# 4             white  ...        15.0  2189-11-30 10:34:32
#
#                OUTTIME     LOS SUBJECT_IDic_ HADM_IDic_  \
# 0  2181-11-28 20:59:25  3.0786         55973     152234
# 1  2199-08-08 17:09:18  5.8884         27513     163557
# 2  2159-09-04 19:08:10  1.3194         10950     189514
# 3  2109-02-18 17:03:12  1.2914         20707     129310
# 4  2189-12-02 14:17:37  2.1549         29904     129607
#
#           INTIME_COLLAPSED        OUTTIME_COLLAPSED  age_group dod_exists
# 0  2011-09-04 19:06:12 UTC  2011-09-07 20:59:23 UTC  60.0-79.0       True
# 1  2007-07-13 19:50:04 UTC  2007-07-19 17:09:21 UTC  40.0-59.0       True
# 2  2004-11-22 11:28:14 UTC  2004-11-23 19:08:10 UTC  40.0-59.0       True
# 3  2001-07-22 10:03:37 UTC  2001-07-23 17:03:13 UTC  40.0-59.0      False
# 4  2006-11-20 10:34:32 UTC  2006-11-22 14:17:35 UTC  40.0-59.0      False
#
# [5 rows x 56 columns]

# %%
#checking the column for binary dod_exists is correct
print('length of df:',len(admissions_with_diagnosis))
print('no. of True dod_exists:',len(admissions_with_diagnosis[admissions_with_diagnosis['dod_exists']]))

print('length of df minus number of nulls in dod column:',len(admissions_with_diagnosis) - admissions_with_diagnosis.isnull().sum()['dod'])
# Out:
# length of df: 61532
# no. of True dod_exists: 24184
# length of df minus number of nulls in dod column: 24184

# %%
admissions_with_diagnosis.head()
# Out:
#    icustay_id  subject_id   hadm_id gender                  dod  \
# 0      200001     55973.0  152234.0      F  2182-11-26 00:00:00
# 1      200003     27513.0  163557.0      M  2199-10-17 00:00:00
# 2      200006     10950.0  189514.0      M  2160-05-14 00:00:00
# 3      200007     20707.0  129310.0      M                  NaN
# 4      200009     29904.0  129607.0      F                  NaN
#
#              admittime            dischtime  los_hospital   age  \
# 0  2181-11-18 16:04:00  2181-12-04 13:42:00          16.0  61.0
# 1  2199-08-02 17:02:00  2199-08-22 19:00:00          20.0  48.0
# 2  2159-09-03 11:27:00  2159-09-05 18:45:00           2.0  54.0
# 3  2109-02-17 10:02:00  2109-02-20 15:47:00           3.0  44.0
# 4  2189-11-30 10:45:00  2189-12-06 15:00:00           6.0  47.0
#
#   ethnicity_grouped  ... LAST_WARDID               INTIME  \
# 0             asian  ...        23.0  2181-11-25 19:06:12
# 1             white  ...        57.0  2199-08-02 19:50:04
# 2             other  ...        52.0  2159-09-03 11:28:14
# 3             white  ...        57.0  2109-02-17 10:03:37
# 4             white  ...        15.0  2189-11-30 10:34:32
#
#                OUTTIME     LOS SUBJECT_IDic_ HADM_IDic_  \
# 0  2181-11-28 20:59:25  3.0786         55973     152234
# 1  2199-08-08 17:09:18  5.8884         27513     163557
# 2  2159-09-04 19:08:10  1.3194         10950     189514
# 3  2109-02-18 17:03:12  1.2914         20707     129310
# 4  2189-12-02 14:17:37  2.1549         29904     129607
#
#           INTIME_COLLAPSED        OUTTIME_COLLAPSED  age_group dod_exists
# 0  2011-09-04 19:06:12 UTC  2011-09-07 20:59:23 UTC  60.0-79.0       True
# 1  2007-07-13 19:50:04 UTC  2007-07-19 17:09:21 UTC  40.0-59.0       True
# 2  2004-11-22 11:28:14 UTC  2004-11-23 19:08:10 UTC  40.0-59.0       True
# 3  2001-07-22 10:03:37 UTC  2001-07-23 17:03:13 UTC  40.0-59.0      False
# 4  2006-11-20 10:34:32 UTC  2006-11-22 14:17:35 UTC  40.0-59.0      False
#
# [5 rows x 56 columns]

# %%
admissions_with_diagnosis.columns
# Out:
# Index(['icustay_id', 'subject_id', 'hadm_id', 'gender', 'dod', 'admittime',
#        'dischtime', 'los_hospital', 'age', 'ethnicity_grouped',
#        'admission_type', 'hospital_expire_flag', 'hospstay_seq',
#        'first_hosp_stay', 'intime', 'outtime', 'los_icu', 'icustay_seq',
#        'first_icu_stay', 'category', 'first_category', 'blood', 'circulatory',
#        'congenital', 'digestive', 'genitourinary', 'ill-defined',
#        'infectious|parasitic', 'injury|poisoning', 'mental',
#        'metabolic|immunity', 'musculoskeletal', 'neoplasms', 'nervous',
#        'perinatal', 'pregnancy complications', 'respiratory', 'skin',
#        'unclassified', 'ROW_ID', 'SUBJECT_IDawd_', 'HADM_IDawd_', 'DBSOURCE',
#        'FIRST_CAREUNIT', 'LAST_CAREUNIT', 'FIRST_WARDID', 'LAST_WARDID',
#        'INTIME', 'OUTTIME', 'LOS', 'SUBJECT_IDic_', 'HADM_IDic_',
#        'INTIME_COLLAPSED', 'OUTTIME_COLLAPSED', 'age_group', 'dod_exists'],
#       dtype='object')

# %%
admissions_with_diagnosis = admissions_with_diagnosis.drop(['SUBJECT_IDic_', 'HADM_IDic_'], axis=1)

# %%
#admissions_with_diagnosis = admissions_with_diagnosis.drop(['INTIME_COLLAPSEDawd_', 'OUTTIME_COLLAPSEDawd_'], axis=1)

# %% [markdown]
# # Add Sepsis Info Back

# %%
admissions_with_diagnosis = admissions_with_diagnosis.join(patients_with_sepsis, on=['subject_id', 'hadm_id']).fillna({'sepsis': False})

admissions_with_diagnosis.head()
# Out:
#    icustay_id  subject_id   hadm_id gender                  dod  \
# 0      200001     55973.0  152234.0      F  2182-11-26 00:00:00
# 1      200003     27513.0  163557.0      M  2199-10-17 00:00:00
# 2      200006     10950.0  189514.0      M  2160-05-14 00:00:00
# 3      200007     20707.0  129310.0      M                  NaN
# 4      200009     29904.0  129607.0      F                  NaN
#
#              admittime            dischtime  los_hospital   age  \
# 0  2181-11-18 16:04:00  2181-12-04 13:42:00          16.0  61.0
# 1  2199-08-02 17:02:00  2199-08-22 19:00:00          20.0  48.0
# 2  2159-09-03 11:27:00  2159-09-05 18:45:00           2.0  54.0
# 3  2109-02-17 10:02:00  2109-02-20 15:47:00           3.0  44.0
# 4  2189-11-30 10:45:00  2189-12-06 15:00:00           6.0  47.0
#
#   ethnicity_grouped  ... FIRST_WARDID  LAST_WARDID               INTIME  \
# 0             asian  ...         23.0         23.0  2181-11-25 19:06:12
# 1             white  ...         57.0         57.0  2199-08-02 19:50:04
# 2             other  ...         52.0         52.0  2159-09-03 11:28:14
# 3             white  ...         57.0         57.0  2109-02-17 10:03:37
# 4             white  ...         15.0         15.0  2189-11-30 10:34:32
#
#                OUTTIME     LOS         INTIME_COLLAPSED  \
# 0  2181-11-28 20:59:25  3.0786  2011-09-04 19:06:12 UTC
# 1  2199-08-08 17:09:18  5.8884  2007-07-13 19:50:04 UTC
# 2  2159-09-04 19:08:10  1.3194  2004-11-22 11:28:14 UTC
# 3  2109-02-18 17:03:12  1.2914  2001-07-22 10:03:37 UTC
# 4  2189-12-02 14:17:37  2.1549  2006-11-20 10:34:32 UTC
#
#          OUTTIME_COLLAPSED  age_group dod_exists sepsis
# 0  2011-09-07 20:59:23 UTC  60.0-79.0       True  False
# 1  2007-07-19 17:09:21 UTC  40.0-59.0       True   True
# 2  2004-11-23 19:08:10 UTC  40.0-59.0       True  False
# 3  2001-07-23 17:03:13 UTC  40.0-59.0      False  False
# 4  2006-11-22 14:17:35 UTC  40.0-59.0      False  False
#
# [5 rows x 55 columns]

# %%
#investigation into sepsis
#corresponds with what we expect. 
#10% of patients who die, had sepsis
#28% of patients who die, did not have sepsis

#54% of patients who do not die, do not have sepsis

death_with_sepsis = admissions_with_diagnosis.groupby(['dod_exists', 'sepsis']).size()
(death_with_sepsis / sum(death_with_sepsis))
# Out:
# dod_exists  sepsis
# False       False     0.551242
#             True      0.055727
# True        False     0.299828
#             True      0.093204
# dtype: float64

# %% [markdown]
# # Merge diagnosis categories
# - 'perinatal' = ('congenital', 'perinatal', 'pregnancy complications')
# - 'circulatory' = ('circulatory', 'blood')
# - 'other' = ('ill-defined', 'unclassified',  'genitourinary', 'skin')

# %%
#list of unique diagnosis before transformation
print(len(admissions_with_diagnosis['first_category'].unique()))
list(admissions_with_diagnosis['first_category'].unique())
# Out:
# 19
# ['skin',
#  'infectious|parasitic',
#  'injury|poisoning',
#  'circulatory',
#  'digestive',
#  'respiratory',
#  'perinatal',
#  'nervous',
#  'neoplasms',
#  'mental',
#  'metabolic|immunity',
#  'musculoskeletal',
#  'congenital',
#  'genitourinary',
#  'ill-defined',
#  'blood',
#  'unclassified',
#  'pregnancy complications',
#  nan]

# %%
def merge_first_categories(df):
    #perinatal' = ('congenital', 'perinatal', 'pregnancy complications')
    df.replace(to_replace =["congenital", 'pregnancy complications'], value ="perinatal", inplace=True) 
    
    #circulatory' = ('circulatory', 'blood')
    df.replace(to_replace ="blood", value ="circulatory", inplace=True) 
    
    #other' = ('ill-defined', 'unclassified',  'genitourinary', 'skin')
    df.replace(to_replace =['ill-defined', 'unclassified', 'genitourinary', 'skin'], value ='other', inplace=True) 
    return df

admissions_with_diagnosis = merge_first_categories(admissions_with_diagnosis)

# %%
#list of unique diagnosis after transformation
print(len(admissions_with_diagnosis['first_category'].unique()))
list(admissions_with_diagnosis['first_category'].unique())
# Out:
# 13
# ['other',
#  'infectious|parasitic',
#  'injury|poisoning',
#  'circulatory',
#  'digestive',
#  'respiratory',
#  'perinatal',
#  'nervous',
#  'neoplasms',
#  'mental',
#  'metabolic|immunity',
#  'musculoskeletal',
#  nan]

# %% [markdown]
# # Add Diagnosis counts column

# %%
def add_diagnosis_counts(df):
    diagnoses_df = df[['blood', 'circulatory',
       'congenital', 'digestive', 'genitourinary', 'ill-defined',
       'infectious|parasitic', 'injury|poisoning', 'mental',
       'metabolic|immunity', 'musculoskeletal', 'neoplasms', 'nervous',
       'perinatal', 'pregnancy complications', 'respiratory', 'skin',
       'unclassified']]
    
    df['diagnoses_count'] = diagnoses_df.sum(axis=1)
    return df

# %%
admissions_with_diagnosis = add_diagnosis_counts(admissions_with_diagnosis)

# %%
len(admissions_with_diagnosis.columns)
# Out:
# 56

# %% [markdown]
# # Write to csv

# %%
admissions_with_diagnosis.head()
# Out:
#    icustay_id  subject_id   hadm_id gender                  dod  \
# 0      200001     55973.0  152234.0      F  2182-11-26 00:00:00
# 1      200003     27513.0  163557.0      M  2199-10-17 00:00:00
# 2      200006     10950.0  189514.0      M  2160-05-14 00:00:00
# 3      200007     20707.0  129310.0      M                  NaN
# 4      200009     29904.0  129607.0      F                  NaN
#
#              admittime            dischtime  los_hospital   age  \
# 0  2181-11-18 16:04:00  2181-12-04 13:42:00          16.0  61.0
# 1  2199-08-02 17:02:00  2199-08-22 19:00:00          20.0  48.0
# 2  2159-09-03 11:27:00  2159-09-05 18:45:00           2.0  54.0
# 3  2109-02-17 10:02:00  2109-02-20 15:47:00           3.0  44.0
# 4  2189-11-30 10:45:00  2189-12-06 15:00:00           6.0  47.0
#
#   ethnicity_grouped  ... LAST_WARDID               INTIME  \
# 0             asian  ...        23.0  2181-11-25 19:06:12
# 1             white  ...        57.0  2199-08-02 19:50:04
# 2             other  ...        52.0  2159-09-03 11:28:14
# 3             white  ...        57.0  2109-02-17 10:03:37
# 4             white  ...        15.0  2189-11-30 10:34:32
#
#                OUTTIME     LOS         INTIME_COLLAPSED  \
# 0  2181-11-28 20:59:25  3.0786  2011-09-04 19:06:12 UTC
# 1  2199-08-08 17:09:18  5.8884  2007-07-13 19:50:04 UTC
# 2  2159-09-04 19:08:10  1.3194  2004-11-22 11:28:14 UTC
# 3  2109-02-18 17:03:12  1.2914  2001-07-22 10:03:37 UTC
# 4  2189-12-02 14:17:37  2.1549  2006-11-20 10:34:32 UTC
#
#          OUTTIME_COLLAPSED  age_group  dod_exists sepsis diagnoses_count
# 0  2011-09-07 20:59:23 UTC  60.0-79.0        True  False            20.0
# 1  2007-07-19 17:09:21 UTC  40.0-59.0        True   True             6.0
# 2  2004-11-23 19:08:10 UTC  40.0-59.0        True  False             8.0
# 3  2001-07-23 17:03:13 UTC  40.0-59.0       False  False             7.0
# 4  2006-11-22 14:17:35 UTC  40.0-59.0       False  False             6.0
#
# [5 rows x 56 columns]

# %%
print('length of csv:',len(admissions_with_diagnosis))
# Out:
# length of csv: 61532

# %%
# Chloe's address
#admissions_with_diagnosis.to_csv('/Users/chloemaine/Documents/Chloe/BGSE/masters_project/processed_data/admissions_with_diagnosis_assigned_icu.csv', index=False)

# %% [markdown]
# # Add on Ideal ICU column from patient_details_ideal_icu.csv

# %%
len(admissions_with_diagnosis)
# Out:
# 61532

# %%
# Chloe's directory
#os.chdir('/Users/chloemaine/Documents/Chloe/BGSE/masters_project/processed_data')
patient_details_idealicu = pd.read_csv('../input_data/patient_details_idealicu.csv')
patient_details_idealicu = patient_details_idealicu[['subject_id', 'hadm_id', 'icustay_id', 'ideal_ICU']]

# %%
len(patient_details_idealicu)
# Out:
# 61532

# %%
admissions_with_diagnosis = admissions_with_diagnosis.set_index(['subject_id', 'hadm_id', 'icustay_id']).join(patient_details_idealicu.set_index(['subject_id', 'hadm_id', 'icustay_id']))

# %%
len(admissions_with_diagnosis)
# Out:
# 61532

# %%
admissions_with_diagnosis.head()
# Out:
#                                gender                  dod  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001          F  2182-11-26 00:00:00
# 27513.0    163557.0 200003          M  2199-10-17 00:00:00
# 10950.0    189514.0 200006          M  2160-05-14 00:00:00
# 20707.0    129310.0 200007          M                  NaN
# 29904.0    129607.0 200009          F                  NaN
#
#                                           admittime            dischtime  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001      2181-11-18 16:04:00  2181-12-04 13:42:00
# 27513.0    163557.0 200003      2199-08-02 17:02:00  2199-08-22 19:00:00
# 10950.0    189514.0 200006      2159-09-03 11:27:00  2159-09-05 18:45:00
# 20707.0    129310.0 200007      2109-02-17 10:02:00  2109-02-20 15:47:00
# 29904.0    129607.0 200009      2189-11-30 10:45:00  2189-12-06 15:00:00
#
#                                 los_hospital   age ethnicity_grouped  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001              16.0  61.0             asian
# 27513.0    163557.0 200003              20.0  48.0             white
# 10950.0    189514.0 200006               2.0  54.0             other
# 20707.0    129310.0 200007               3.0  44.0             white
# 29904.0    129607.0 200009               6.0  47.0             white
#
#                                admission_type  hospital_expire_flag  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001          EMERGENCY                   0.0
# 27513.0    163557.0 200003          EMERGENCY                   0.0
# 10950.0    189514.0 200006          EMERGENCY                   0.0
# 20707.0    129310.0 200007          EMERGENCY                   0.0
# 29904.0    129607.0 200009           ELECTIVE                   0.0
#
#                                 hospstay_seq  ...               INTIME  \
# subject_id hadm_id  icustay_id                ...
# 55973.0    152234.0 200001               6.0  ...  2181-11-25 19:06:12
# 27513.0    163557.0 200003               1.0  ...  2199-08-02 19:50:04
# 10950.0    189514.0 200006               3.0  ...  2159-09-03 11:28:14
# 20707.0    129310.0 200007               1.0  ...  2109-02-17 10:03:37
# 29904.0    129607.0 200009               1.0  ...  2189-11-30 10:34:32
#
#                                             OUTTIME     LOS  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001      2181-11-28 20:59:25  3.0786
# 27513.0    163557.0 200003      2199-08-08 17:09:18  5.8884
# 10950.0    189514.0 200006      2159-09-04 19:08:10  1.3194
# 20707.0    129310.0 200007      2109-02-18 17:03:12  1.2914
# 29904.0    129607.0 200009      2189-12-02 14:17:37  2.1549
#
#                                        INTIME_COLLAPSED  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001      2011-09-04 19:06:12 UTC
# 27513.0    163557.0 200003      2007-07-13 19:50:04 UTC
# 10950.0    189514.0 200006      2004-11-22 11:28:14 UTC
# 20707.0    129310.0 200007      2001-07-22 10:03:37 UTC
# 29904.0    129607.0 200009      2006-11-20 10:34:32 UTC
#
#                                       OUTTIME_COLLAPSED  age_group dod_exists  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001      2011-09-07 20:59:23 UTC  60.0-79.0       True
# 27513.0    163557.0 200003      2007-07-19 17:09:21 UTC  40.0-59.0       True
# 10950.0    189514.0 200006      2004-11-23 19:08:10 UTC  40.0-59.0       True
# 20707.0    129310.0 200007      2001-07-23 17:03:13 UTC  40.0-59.0      False
# 29904.0    129607.0 200009      2006-11-22 14:17:35 UTC  40.0-59.0      False
#
#                                sepsis  diagnoses_count  ideal_ICU
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001      False             20.0       MICU
# 27513.0    163557.0 200003       True              6.0       SICU
# 10950.0    189514.0 200006      False              8.0       MICU
# 20707.0    129310.0 200007      False              7.0        CCU
# 29904.0    129607.0 200009      False              6.0       CSRU
#
# [5 rows x 54 columns]

# %%
admissions_with_diagnosis = admissions_with_diagnosis.drop(['ROW_ID', 
                                                            'HADM_IDawd_', 
                                                            'SUBJECT_IDawd_',
                                                            'DBSOURCE', 
                                                            'LAST_CAREUNIT', 
                                                            'FIRST_WARDID', 
                                                            'LAST_WARDID',
                                                            'OUTTIME', 
                                                            'LOS',  
                                                            'age', 
                                                            'intime',
                                                            'outtime'], axis=1)

# %%
admissions_with_diagnosis.head()
# Out:
#                                gender                  dod  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001          F  2182-11-26 00:00:00
# 27513.0    163557.0 200003          M  2199-10-17 00:00:00
# 10950.0    189514.0 200006          M  2160-05-14 00:00:00
# 20707.0    129310.0 200007          M                  NaN
# 29904.0    129607.0 200009          F                  NaN
#
#                                           admittime            dischtime  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001      2181-11-18 16:04:00  2181-12-04 13:42:00
# 27513.0    163557.0 200003      2199-08-02 17:02:00  2199-08-22 19:00:00
# 10950.0    189514.0 200006      2159-09-03 11:27:00  2159-09-05 18:45:00
# 20707.0    129310.0 200007      2109-02-17 10:02:00  2109-02-20 15:47:00
# 29904.0    129607.0 200009      2189-11-30 10:45:00  2189-12-06 15:00:00
#
#                                 los_hospital ethnicity_grouped admission_type  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001              16.0             asian      EMERGENCY
# 27513.0    163557.0 200003              20.0             white      EMERGENCY
# 10950.0    189514.0 200006               2.0             other      EMERGENCY
# 20707.0    129310.0 200007               3.0             white      EMERGENCY
# 29904.0    129607.0 200009               6.0             white       ELECTIVE
#
#                                 hospital_expire_flag  hospstay_seq  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001                       0.0           6.0
# 27513.0    163557.0 200003                       0.0           1.0
# 10950.0    189514.0 200006                       0.0           3.0
# 20707.0    129310.0 200007                       0.0           1.0
# 29904.0    129607.0 200009                       0.0           1.0
#
#                                first_hosp_stay  ...  unclassified  \
# subject_id hadm_id  icustay_id                  ...
# 55973.0    152234.0 200001               False  ...           2.0
# 27513.0    163557.0 200003                True  ...           0.0
# 10950.0    189514.0 200006               False  ...           1.0
# 20707.0    129310.0 200007                True  ...           1.0
# 29904.0    129607.0 200009                True  ...           1.0
#
#                                 FIRST_CAREUNIT               INTIME  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001                MICU  2181-11-25 19:06:12
# 27513.0    163557.0 200003                SICU  2199-08-02 19:50:04
# 10950.0    189514.0 200006                MICU  2159-09-03 11:28:14
# 20707.0    129310.0 200007                 CCU  2109-02-17 10:03:37
# 29904.0    129607.0 200009                CSRU  2189-11-30 10:34:32
#
#                                        INTIME_COLLAPSED  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001      2011-09-04 19:06:12 UTC
# 27513.0    163557.0 200003      2007-07-13 19:50:04 UTC
# 10950.0    189514.0 200006      2004-11-22 11:28:14 UTC
# 20707.0    129310.0 200007      2001-07-22 10:03:37 UTC
# 29904.0    129607.0 200009      2006-11-20 10:34:32 UTC
#
#                                       OUTTIME_COLLAPSED  age_group  \
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001      2011-09-07 20:59:23 UTC  60.0-79.0
# 27513.0    163557.0 200003      2007-07-19 17:09:21 UTC  40.0-59.0
# 10950.0    189514.0 200006      2004-11-23 19:08:10 UTC  40.0-59.0
# 20707.0    129310.0 200007      2001-07-23 17:03:13 UTC  40.0-59.0
# 29904.0    129607.0 200009      2006-11-22 14:17:35 UTC  40.0-59.0
#
#                                 dod_exists  sepsis  diagnoses_count  ideal_ICU
# subject_id hadm_id  icustay_id
# 55973.0    152234.0 200001            True   False             20.0       MICU
# 27513.0    163557.0 200003            True    True              6.0       SICU
# 10950.0    189514.0 200006            True   False              8.0       MICU
# 20707.0    129310.0 200007           False   False              7.0        CCU
# 29904.0    129607.0 200009           False   False              6.0       CSRU
#
# [5 rows x 42 columns]

# %% [markdown]
# # Drop rows where intime_trans_collapsed is null
# (10 rows to drop)

# %%
admissions_with_diagnosis.reset_index(inplace=True)

# %%
admissions_with_diagnosis.columns
# Out:
# Index(['subject_id', 'hadm_id', 'icustay_id', 'gender', 'dod', 'admittime',
#        'dischtime', 'los_hospital', 'ethnicity_grouped', 'admission_type',
#        'hospital_expire_flag', 'hospstay_seq', 'first_hosp_stay', 'los_icu',
#        'icustay_seq', 'first_icu_stay', 'category', 'first_category', 'blood',
#        'circulatory', 'congenital', 'digestive', 'genitourinary',
#        'ill-defined', 'infectious|parasitic', 'injury|poisoning', 'mental',
#        'metabolic|immunity', 'musculoskeletal', 'neoplasms', 'nervous',
#        'perinatal', 'pregnancy complications', 'respiratory', 'skin',
#        'unclassified', 'FIRST_CAREUNIT', 'INTIME', 'INTIME_COLLAPSED',
#        'OUTTIME_COLLAPSED', 'age_group', 'dod_exists', 'sepsis',
#        'diagnoses_count', 'ideal_ICU'],
#       dtype='object')

# %%
drop_indexes = admissions_with_diagnosis[admissions_with_diagnosis['INTIME_COLLAPSED'].isnull()].index
len(drop_indexes)
# Out:
# 0

# %%
admissions_with_diagnosis = admissions_with_diagnosis.drop(drop_indexes)

# %%
len(admissions_with_diagnosis)
# Out:
# 61532

# %% [markdown]
# # output csv
# will go into data_split.ipynb

# %%
#this csv will go into data_split.ipynb
admissions_with_diagnosis.to_csv('../output_data/cleaned_data_ideal_and_assigned.csv', index=False)
